# %% [markdown]
# # Getting the Data into a SQL Database

# %% [markdown]
# This notebook takes CSV that contains meta features and information about complaints and loads it into a PostgreSQL database.
#
# First, need to load the required packages.

# %%
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd
from sklearn.externals import joblib

# %%
# Set Postgres credentials
db_name = 'complaint1'
username = 'postgres'
host = 'localhost'
port = '5432' 
#password = ''

# %%
engine = create_engine( 'postgresql://{}:{}@{}:{}/{}'.format(username, password, host, port, db_name) )

# %%
## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
# read a database from CSV and load it into a pandas dataframe
complaint = pd.read_csv('nars_clean_meta_28jan.csv', index_col=0)

# %%
complaint.to_sql(
    name=db_name, 
    con=engine,
    if_exists='append'
)

# %%
#connect to make queries using psycopg2
con = None
con = psycopg2.connect(database=db_name, 
    host='localhost',
    user=username,
    password=password)

# query:
sql_query = """
SELECT * FROM complaint1;
"""
test_data_from_sql = pd.read_sql_query(sql_query,con)
test_data_from_sql.head()
# Out:
#    level_0  index    date_rec  \
# 0        0    177  01/11/2019
# 1        1    186  01/11/2019
# 2        2    188  01/11/2019
# 3        3    189  01/11/2019
# 4        4    195  01/11/2019
#
#                                                 prod  \
# 0                                           Mortgage
# 1                                           Mortgage
# 2  Credit reporting, credit repair services, or o...
# 3                                    Debt collection
# 4                                           Mortgage
#
#                       subprod  \
# 0  Conventional home mortgage
# 1  Conventional home mortgage
# 2            Credit reporting
# 3                  Other debt
# 4                 VA mortgage
#
#                                                issue  \
# 0  Applying for a mortgage or refinancing an exis...
# 1  Applying for a mortgage or refinancing an exis...
# 2                        Improper use of your report
# 3                  Attempts to collect debt not owed
# 4                     Trouble during payment process
#
#                                            sub_issue  \
# 0                                               None
# 1                                               None
# 2  Credit inquiries on your report that you don't...
# 3                                  Debt is not yours
# 4                                               None
#
#                                            narrative  \
# 0  wells fargo charging exorbitant amount fees at...
# 1  filed several complaints wells fargo, opposing...
# 2                   negative remark report recognize
# 3  xx xx 2016, debt 160 00 appeared credit report...
# 4  mortgage xxxx sold flagstar tried process firs...
#
#                                             pub_resp  \
# 0  Company has responded to the consumer and the ...
# 1  Company has responded to the consumer and the ...
# 2  Company has responded to the consumer and the ...
# 3  Company believes it acted appropriately as aut...
# 4  Company has responded to the consumer and the ...
#
#                                      company    ...     PRON PROPN PUNCT  \
# 0                      WELLS FARGO & COMPANY    ...     37.0  94.0    62
# 1                      WELLS FARGO & COMPANY    ...      7.0  27.0    26
# 2  HCFS Health Care Financial Services, Inc.    ...      1.0   NaN     2
# 3                    Penn Credit Corporation    ...     18.0  10.0    26
# 4                         FLAGSTAR BANK, FSB    ...     22.0   5.0    19
#
#   SPACE  SYM   VERB   X avg_words_sent num_sent  num_word
# 0   NaN  2.0  144.0 NaN      34.545455       22       760
# 1   NaN  1.0   38.0 NaN      30.125000        8       241
# 2   NaN  NaN    2.0 NaN      12.000000        1        12
# 3   NaN  2.0   45.0 NaN      21.333333       12       256
# 4   1.0  NaN   48.0 NaN      22.444444        9       202
#
# [5 rows x 41 columns]

# %%
test_data_from_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356699 entries, 0 to 356698
# Data columns (total 41 columns):
# level_0            356699 non-null int64
# index              356699 non-null int64
# date_rec           356699 non-null object
# prod               356699 non-null object
# subprod            304629 non-null object
# issue              356699 non-null object
# sub_issue          246916 non-null object
# narrative          356698 non-null object
# pub_resp           173557 non-null object
# company            356699 non-null object
# state              355349 non-null object
# zip                277815 non-null object
# Tags               61578 non-null object
# consent            356699 non-null object
# how_submit         356699 non-null object
# date_to_company    356699 non-null object
# comp_resp          356699 non-null object
# timely_resp        356699 non-null object
# cons_disp          162981 non-null object
# id                 356699 non-null int64
# response           356699 non-null object
# sentiment          356699 non-null int64
# ADJ                351978 non-null float64
# ADP                353109 non-null float64
# ADV                341563 non-null float64
# CCONJ              330894 non-null float64
# DET                347026 non-null float64
# INTJ               72997 non-null float64
# NOUN               356292 non-null float64
# NUM                244636 non-null float64
# PART               307985 non-null float64
# PRON               341544 non-null float64
# PROPN              329259 non-null float64
# PUNCT              356699 non-null int64
# SPACE              150390 non-null float64
# SYM                206881 non-null float64
# VERB               355810 non-null float64
# X                  23500 non-null float64
# avg_words_sent     356699 non-null float64
# num_sent           356699 non-null int64
# num_word           356699 non-null int64
# dtypes: float64(16), int64(7), object(18)
# memory usage: 111.6+ MB

# %% [markdown]
# Looks like it was successful. Now we can use this database to fit and train models.
